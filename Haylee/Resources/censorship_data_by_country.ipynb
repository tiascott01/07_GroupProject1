# %%
# Module Imports
import pandas as pd
from pathlib import Path

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = Path("Censorship_Data_by_Country.csv")
censorship_df = pd.read_csv(csv_path)
censorship_df.head()
# Out:
#    Flag      Country  Score Torrents Restricted?  \
# 0  :af:  Afghanistan      6                    Y
# 1  :al:      Albania      2                    Y
# 2  :dz:      Algeria      5                    Y
# 3  :ad:      Andorra      1                    Y
# 4  :ao:       Angola      2                    Y
#
#   Torrents Banned or Shut Down? Pornography Restricted? Pornography Banned?  \
# 0                             N                       Y                   Y
# 1                             N                       N                   N
# 2                             N                       Y                   N
# 3                             N                       N                   N
# 4                             N                       N                   N
#
#   Political Media Restricted? Political Media Heavily Censored?  \
# 0                           Y                                 Y
# 1                           Y                                 N
# ...

# %%
# Sort the data by Score
sorted_df = censorship_df.sort_values("Score", ascending=False)
sorted_df.head(20)
# Out:
#      Flag               Country  Score Torrents Restricted?  \
# 32   :cn:                 China     11                    Y
# 115  :kp:           North Korea     11                    Y
# 72   :ir:                  Iran      9                    Y
# 165  :ae:  United Arab Emirates      9                    Y
# 107  :mm:       Myanmar (Burma)      9                    Y
# 162  :tm:          Turkmenistan      9                    Y
# 127  :qa:                 Qatar      8                    Y
# 117  :om:                  Oman      8                    Y
# 151  :sy:                 Syria      8                    Y
# 118  :pk:              Pakistan      8                    Y
# 155  :th:              Thailand      8                    Y
# 169  :uz:            Uzbekistan      8                    Y
# 161  :tr:                Turkey      8                    Y
# 12   :by:               Belarus      8                    Y
# 130  :ru:                Russia      7                    Y
# ...
