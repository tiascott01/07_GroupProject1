# %%
import pandas as pd

#import csv
df = pd.read_csv('/Users/alisonlove/Bootcamp/07_GroupProject1/Resources/internet-data.csv')
df.head()
# Out:
#            Country Edition  1.1.1) Internet users  \
# 0  A-United States      E1                   81.5
# 1  A-United States      E2                   81.9
# 2  A-United States      E3                   83.8
# 3  A-United States      E4                   85.3
# 4  A-United States      E5                   85.3
#
#    1.1.2) Fixed-line broadband subscribers  1.1.3) Mobile subscribers  \
# 0                                    31.85                      119.1
# 1                                    32.73                      122.6
# 2                                    33.28                      123.0
# 3                                    33.89                      129.0
# 4                                    34.72                      134.5
#
#    1.1.4) Gender gap in internet access  \
# 0                                   NaN
# 1                                   1.1
# 2                                  -3.4
# 3                                   1.1
# ...

# %%
#find empty values
df.isnull().sum()
# Out:
# Country                                           0
# Edition                                           0
# 1.1.1) Internet users                             0
# 1.1.2) Fixed-line broadband subscribers           0
# 1.1.3) Mobile subscribers                         0
#                                                ...
# BG20) Male internet users                       120
# BG21) Female internet users                     120
# BG22) Male mobile phone subscribers               0
# BG23) Female mobile phone subscribers             0
# BG24) Total fixed line broadband subscribers      0
# Length: 86, dtype: int64

# %%
df.dtypes
# Out:
# Country                                          object
# Edition                                          object
# 1.1.1) Internet users                           float64
# 1.1.2) Fixed-line broadband subscribers         float64
# 1.1.3) Mobile subscribers                       float64
#                                                  ...
# BG20) Male internet users                       float64
# BG21) Female internet users                     float64
# BG22) Male mobile phone subscribers             float64
# BG23) Female mobile phone subscribers           float64
# BG24) Total fixed line broadband subscribers      int64
# Length: 86, dtype: object
